# %% [markdown]
# <a href="https://colab.research.google.com/github/dspraneeth07/AXIOM--SQL-REFLEX-AGENT-v4/blob/main/notebooks/02_graphrag_cartographer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/dspraneeth07/AXIOM--SQL-REFLEX-AGENT-v4.git
# %cd AXIOM--SQL-REFLEX-AGENT-v4
# Out:
# Cloning into 'AXIOM--SQL-REFLEX-AGENT-v4'...
# remote: Enumerating objects: 37, done.
# remote: Counting objects: 100% (37/37), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 37 (delta 14), reused 12 (delta 4), pack-reused 0 (from 0)
# Receiving objects: 100% (37/37), 1.25 MiB | 10.62 MiB/s, done.
# Resolving deltas: 100% (14/14), done.
# /content/AXIOM--SQL-REFLEX-AGENT-v4
